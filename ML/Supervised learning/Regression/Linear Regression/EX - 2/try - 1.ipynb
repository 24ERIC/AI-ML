# %% [markdown]
# ### Info
# 1.
# 1.
# 1.
# 1.
#
# ### Questions
# 1.
# 1.
# 1.
# 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import statsmodels.api as sm
from statsmodels.formula.api import ols

import numpy as np
import statsmodels.formula.api as smf

# %%
data = pd.read_csv("input/Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Info
# 1. keys are tv, radio, newspaper, sales
# 1. sales is number of items sold
# 1.
# 1.
#
# ### Questions
# 1. What is "Unnamed", remove it? or fill with some value?
# 1. is it the price for tv, radio and newspaper -> why there's 230 and 17$ for a TV
# 1.
# 1.

# %%
data.drop(data.columns[0], axis=1, inplace=True)

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
data.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ### Info
# 1. in totol, there are 200 lines of data
# 1. exist 0 in radio column
# 1.
# 1.
#
# ### Questions
# 1.
# 1.
# 1.
# 1.

# %%
plt.scatter(x=data['TV'], y=data['sales'])

plt.title('scatter plot')
plt.xlabel('TV Adveretising')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(x=data['newspaper'], y=data['sales'])

plt.title('scatter plot')
plt.xlabel('newspaper')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(x=data['radio'], y=data['sales'])

plt.title('scatter plot')
plt.xlabel('radio')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(x=data['TV'], y=data['newspaper'])

plt.title('scatter plot')
plt.xlabel('TV Adveretising')
plt.ylabel('newspaper')
# Out:
# Text(0, 0.5, 'newspaper')

# %%
plt.scatter(x=data['radio'], y=data['newspaper'])

plt.title('scatter plot')
plt.xlabel('radio')
plt.ylabel('newspaper')
# Out:
# Text(0, 0.5, 'newspaper')

# %%
formula = 'sales ~ TV'
model1 = smf.ols(formula=formula, data=data).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):           1.47e-42
# Time:                        12:47:43   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
sns.regplot(x="TV", y="sales", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
sns.regplot(x="newspaper", y="sales", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
sns.regplot(x="radio", y="sales", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
sns.regplot(x="TV", y="newspaper", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
sns.regplot(x="TV", y="radio", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
sns.regplot(x="radio", y="newspaper", data=data,color='#1F77B4',line_kws={'color':'red'},ci=None).set(title = 'Linear Fit')
# Out:
# [Text(0.5, 1.0, 'Linear Fit')]

# %%
data.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000
